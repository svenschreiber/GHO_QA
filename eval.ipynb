# %%
from sql_rag_ollama import SQLRAG
import pandas as pd
import time

# %%
model = SQLRAG()

# %%
df = pd.read_csv("data/eval_cases.csv", sep=",")
times = []
for question in df["Question"]:
    start_time = time.perf_counter()
    print("Question:", question)
    model.prompt(question, print_results=True)
    print()
    end_time = time.perf_counter()
    times.append(end_time - start_time)

print(times)
# Out:
# Question: What prevalence of diabetes was recorded in germany in 2015 for males in the age group 18+?
# |    |   value |
# |---:|--------:|
# |  0 |  8.1332 |
#
# In 2015, the age-standardized prevalence of diabetes among males aged 18 years and older in Germany was recorded at approximately 8.13%. This statistic provides insight into the burden of diabetes within this demographic group during that year.
#
# Question: What prevalence of diabetes was recorded in germany in 2015 for males in the age group 30+?
# |    |   value |
# |---:|--------:|
# |  0 | 11.0239 |
#
# In 2015, Germany recorded an age-standardized prevalence rate of diabetes at approximately 11.02% among males aged 30 years and older.
#
# Question: What prevalence of diabetes was recorded in germany in 2015 for females in the age group 18+?
# |    |   value |
# |---:|--------:|
# |  0 | 5.18364 |
#
# ...

# %%
import requests
import json

values = []
i = 0
site = "indicatordefinitions"
while True:
    data = requests.get(f"https://www.who.int/api/news/{site}?$skip={i}").json()
    print(i)
    if not data['value']: break
    values += data['value']
    i+=50

with open("data/" + site + ".json", "w") as f:
    json.dump(values, f)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300

# %%
with open("data/indicatordefinitions.json", "r") as f:
    defs = json.load(f)

with open("data/indicatormetadataregistrydefinitions.json", "r") as f:
    metadata = json.load(f)

result = [(i,ind) for i, ind in enumerate(defs) if ind["Code"] is not None and "NCD_DIABETES_PREVALENCE_AGESTD" in ind["Code"]]
#id = result[0]["Id"]

[md for md in metadata if md["Id"] == id]
#metadata
(result[0][0] // 50) * 50
# Out:
# 2200
